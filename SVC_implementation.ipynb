# %% [markdown]
# # Support Vector Classifier

# %%
from sklearn.svm import SVC
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import datasets

# %%
df=datasets.load_iris(as_frame=True).frame
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.isnull().sum()
df.shape
# Out:
# (150, 5)

# %%
X=df.drop("target",axis=1)
Y=df["target"]

# %% [markdown]
# # scaling input feature is very imp in SVC

# %%
X_train,X_test,Y_train,Y_test=train_test_split(
    X,
    Y,
    test_size=0.3,
    random_state=42,
    stratify=Y
    
)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
# model
svc=SVC()
svc.fit(X_train_scaled,Y_train)
# Out:
# SVC()

# %%
y_pre=svc.predict(X_test_scaled)

# %%
# model evaluation
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,classification_report

# %%
print("model accuracy is: ",accuracy_score(Y_test,y_pre)*100,"%")
print("model classification report: \n: ", classification_report(Y_test,y_pre))
# Out:
# model accuracy is:  93.33333333333333 %
# model classification report:
# :                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       0.88      0.93      0.90        15
#            2       0.93      0.87      0.90        15
#
#     accuracy                           0.93        45
#    macro avg       0.93      0.93      0.93        45
# weighted avg       0.93      0.93      0.93        45

# %% [markdown]
# # For Linear Kernel

# %%
# model
svc=SVC(kernel="linear")
svc.fit(X_train_scaled,Y_train)

y_pre=svc.predict(X_test_scaled)


print("model accuracy is: ",accuracy_score(Y_test,y_pre)*100,"%")
# Out:
# model accuracy is:  91.11111111111111 %

# %%
# For Polynomial kernel

# %%
# model
svc=SVC(kernel="poly")
svc.fit(X_train_scaled,Y_train)

y_pre=svc.predict(X_test_scaled)


print("model accuracy is: ",accuracy_score(Y_test,y_pre)*100,"%")
# Out:
# model accuracy is:  86.66666666666667 %

# %% [markdown]
# # For sigmoid kernel

# %%
# model
svc=SVC(kernel="sigmoid")
svc.fit(X_train_scaled,Y_train)

y_pre=svc.predict(X_test_scaled)


print("model accuracy is: ",accuracy_score(Y_test,y_pre)*100,"%")
# Out:
# model accuracy is:  91.11111111111111 %

# %% [markdown]
# # For different C values

# %%
c_vals=[0.5,1,2,3,4,5]
for c_val in c_vals:
    # model
    svc=SVC(C=c_val,kernel="rbf")
    svc.fit(X_train_scaled,Y_train)
    
    y_pre=svc.predict(X_test_scaled)
    
    
    print("C = ",c_val,"& model accuracy is: ",accuracy_score(Y_test,y_pre)*100,"%")
# Out:
# C =  0.5 & model accuracy is:  91.11111111111111 %
# C =  1 & model accuracy is:  93.33333333333333 %
# C =  2 & model accuracy is:  91.11111111111111 %
# C =  3 & model accuracy is:  91.11111111111111 %
# C =  4 & model accuracy is:  93.33333333333333 %
# C =  5 & model accuracy is:  93.33333333333333 %
